# %%
# from pytickersymbols import PyTickerSymbolsL
import yfinance as yf
import pandas as pd
import numpy as np
import os
import json

import time

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
DATA_PATH = './data'
os.makedirs(DATA_PATH, exist_ok=True)

# %% [markdown]
# # 1. Get all funds listed on the US NASDAQ exchange

# %%
TOTAL_FUNDS = 46861
PAGE_SIZE = 250
EXCHANGE = 'NAS'

# %%
def fetch_funds(exchange=EXCHANGE, page_size=PAGE_SIZE, total=TOTAL_FUNDS):
    # build query
    q = yf.FundQuery('eq', ['exchange', exchange])
    all_results = []

    offset = 0

    while True:
        print(f"Fetching offset {offset} ...")
        # Fetch one page
        page = yf.screen(q, size=page_size, offset=offset)
        # Safety stop: if empty page, stop
        if not page or len(page['quotes']) == 0:
            print("No more results returned → stopping.")
            break
        all_results.extend(page['quotes'])
        # Update offset for next page
        offset += page_size
        # Optional: stop early if we passed expected total
        if offset >= total:
            print("Reached total expected count. Finished.")
            break
        # Optional: avoid request throttling
        time.sleep(0.1)
    return all_results

# %%
# funds_results = fetch_funds()
# Out:
# Fetching offset 0 ...
# Fetching offset 250 ...
# Fetching offset 500 ...
# Fetching offset 750 ...
# Fetching offset 1000 ...
# Fetching offset 1250 ...
# Fetching offset 1500 ...
# Fetching offset 1750 ...
# Fetching offset 2000 ...
# Fetching offset 2250 ...
# Fetching offset 2500 ...
# Fetching offset 2750 ...
# Fetching offset 3000 ...
# Fetching offset 3250 ...
# Fetching offset 3500 ...
# Fetching offset 3750 ...
# Fetching offset 4000 ...
# Fetching offset 4250 ...
# Fetching offset 4500 ...
# Fetching offset 4750 ...
# Fetching offset 5000 ...
# Fetching offset 5250 ...
# Fetching offset 5500 ...
# Fetching offset 5750 ...
# Fetching offset 6000 ...
# Fetching offset 6250 ...
# Fetching offset 6500 ...
# Fetching offset 6750 ...
# Fetching offset 7000 ...
# Fetching offset 7250 ...
# Fetching offset 7500 ...
# Fetching offset 7750 ...
# Fetching offset 8000 ...
# Fetching offset 8250 ...
# Fetching offset 8500 ...
# Fetching offset 8750 ...
# Fetching offset 9000 ...
# Fetching offset 9250 ...
# Fetching offset 9500 ...
# Fetching offset 9750 ...
# Fetching offset 10000 ...
# Fetching offset 10250 ...
# Fetching offset 10500 ...
# Fetching offset 10750 ...
# Fetching offset 11000 ...
# Fetching offset 11250 ...
# Fetching offset 11500 ...
# Fetching offset 11750 ...
# Fetching offset 12000 ...
# Fetching offset 12250 ...
# Fetching offset 12500 ...
# Fetching offset 12750 ...
# Fetching offset 13000 ...
# Fetching offset 13250 ...
# Fetching offset 13500 ...
# Fetching offset 13750 ...
# Fetching offset 14000 ...
# Fetching offset 14250 ...
# Fetching offset 14500 ...
# Fetching offset 14750 ...
# Fetching offset 15000 ...
# Fetching offset 15250 ...
# Fetching offset 15500 ...
# Fetching offset 15750 ...
# Fetching offset 16000 ...
# Fetching offset 16250 ...
# Fetching offset 16500 ...
# Fetching offset 16750 ...
# Fetching offset 17000 ...
# Fetching offset 17250 ...
# Fetching offset 17500 ...
# Fetching offset 17750 ...
# Fetching offset 18000 ...
# Fetching offset 18250 ...
# Fetching offset 18500 ...
# Fetching offset 18750 ...
# Fetching offset 19000 ...
# Fetching offset 19250 ...
# Fetching offset 19500 ...
# Fetching offset 19750 ...
# Fetching offset 20000 ...
# Fetching offset 20250 ...
# Fetching offset 20500 ...
# Fetching offset 20750 ...
# Fetching offset 21000 ...
# Fetching offset 21250 ...
# Fetching offset 21500 ...
# Fetching offset 21750 ...
# Fetching offset 22000 ...
# Fetching offset 22250 ...
# Fetching offset 22500 ...
# Fetching offset 22750 ...
# Fetching offset 23000 ...
# Fetching offset 23250 ...
# Fetching offset 23500 ...
# Fetching offset 23750 ...
# Fetching offset 24000 ...
# Fetching offset 24250 ...
# Fetching offset 24500 ...
# Fetching offset 24750 ...
# Fetching offset 25000 ...
# Fetching offset 25250 ...
# Fetching offset 25500 ...
# Fetching offset 25750 ...
# Fetching offset 26000 ...
# Fetching offset 26250 ...
# Fetching offset 26500 ...
# Fetching offset 26750 ...
# Fetching offset 27000 ...
# Fetching offset 27250 ...
# Fetching offset 27500 ...
# Fetching offset 27750 ...
# Fetching offset 28000 ...
# Fetching offset 28250 ...
# Fetching offset 28500 ...
# Fetching offset 28750 ...
# Fetching offset 29000 ...
# Fetching offset 29250 ...
# Fetching offset 29500 ...
# Fetching offset 29750 ...
# Fetching offset 30000 ...
# Fetching offset 30250 ...
# Fetching offset 30500 ...
# Fetching offset 30750 ...
# Fetching offset 31000 ...
# Fetching offset 31250 ...
# Fetching offset 31500 ...
# Fetching offset 31750 ...
# Fetching offset 32000 ...
# Fetching offset 32250 ...
# Fetching offset 32500 ...
# Fetching offset 32750 ...
# Fetching offset 33000 ...
# Fetching offset 33250 ...
# Fetching offset 33500 ...
# Fetching offset 33750 ...
# Fetching offset 34000 ...
# Fetching offset 34250 ...
# Fetching offset 34500 ...
# Fetching offset 34750 ...
# Fetching offset 35000 ...
# Fetching offset 35250 ...
# Fetching offset 35500 ...
# Fetching offset 35750 ...
# Fetching offset 36000 ...
# Fetching offset 36250 ...
# Fetching offset 36500 ...
# Fetching offset 36750 ...
# Fetching offset 37000 ...
# Fetching offset 37250 ...
# Fetching offset 37500 ...
# Fetching offset 37750 ...
# Fetching offset 38000 ...
# Fetching offset 38250 ...
# Fetching offset 38500 ...
# Fetching offset 38750 ...
# Fetching offset 39000 ...
# Fetching offset 39250 ...
# Fetching offset 39500 ...
# Fetching offset 39750 ...
# Fetching offset 40000 ...
# Fetching offset 40250 ...
# Fetching offset 40500 ...
# Fetching offset 40750 ...
# Fetching offset 41000 ...
# Fetching offset 41250 ...
# Fetching offset 41500 ...
# Fetching offset 41750 ...
# Fetching offset 42000 ...
# Fetching offset 42250 ...
# Fetching offset 42500 ...
# Fetching offset 42750 ...
# Fetching offset 43000 ...
# Fetching offset 43250 ...
# Fetching offset 43500 ...
# Fetching offset 43750 ...
# Fetching offset 44000 ...
# Fetching offset 44250 ...
# Fetching offset 44500 ...
# Fetching offset 44750 ...
# Fetching offset 45000 ...
# Fetching offset 45250 ...
# Fetching offset 45500 ...
# Fetching offset 45750 ...
# Fetching offset 46000 ...
# Fetching offset 46250 ...
# Fetching offset 46500 ...
# Fetching offset 46750 ...
# Reached total expected count. Finished.

# %%
# len(funds_results)
# Out:
# 47000

# %%
# convert to table
funds_df = pd.DataFrame(funds_results)

# %%
funds_df[['symbol', 'regularMarketPrice']].head()
# Out:
#    symbol  regularMarketPrice
# 0  ZZZZIX              10.999
# 1   ZZZAX               1.000
# 2   ZZYYX               7.850
# 3   ZZWWX           24163.530
# 4  ZYXZZX               2.000

# %%
funds_df.to_parquet(os.path.join(DATA_PATH, 'nas_funds.parquet'), index=False)

# %% [markdown]
# # 2. Get all stocks listed on US exchanges
#
# This should give us a list of stock symbols. To get the info, we'll use a different API endpoint (see section 3)

# %%
TOTAL_STOCKS = 10000
PAGE_SIZE = 250
EXCHANGE = [
    # "SHH", # China Shanghai
    # "JPX", # Japan (Tokyo + Osaka)
    # "KOE", # South Korea KOSPI main
    # "TAI", # Taiwan

    # "FRA", # Germany Frankfurt Xetra
    # "LSE", # UK

    "NMS", # NASDAQ main
    "NYQ", # NYSE main
    "ASE", # NYSE American (AMEX)
]

# %%
def fetch_stocks(exchange=EXCHANGE, page_size=PAGE_SIZE, total=TOTAL_STOCKS):
    # build query
    q = yf.EquityQuery('is-in', ['exchange', *exchange])
    all_results = []

    offset = 0

    while True:
        print(f"Fetching offset {offset} ...")
        # Fetch one page
        page = yf.screen(q, size=page_size, offset=offset)
        # Safety stop: if empty page, stop
        if not page or len(page['quotes']) == 0:
            print("No more results returned → stopping.")
            break
        all_results.extend(page['quotes'])
        # Update offset for next page
        offset += page_size
        # Optional: stop early if we passed expected total
        if offset >= total:
            print("Reached total expected count. Finished.")
            break
        # Optional: avoid request throttling
        time.sleep(0.1)
    return all_results

# %%
stocks_result = fetch_stocks()
# Out:
# Fetching offset 0 ...
# Fetching offset 250 ...
# Fetching offset 500 ...
# Fetching offset 750 ...
# Fetching offset 1000 ...
# Fetching offset 1250 ...
# Fetching offset 1500 ...
# Fetching offset 1750 ...
# Fetching offset 2000 ...
# Fetching offset 2250 ...
# Fetching offset 2500 ...
# Fetching offset 2750 ...
# Fetching offset 3000 ...
# Fetching offset 3250 ...
# Fetching offset 3500 ...
# Fetching offset 3750 ...
# Fetching offset 4000 ...
# Fetching offset 4250 ...
# Fetching offset 4500 ...
# Fetching offset 4750 ...
# No more results returned → stopping.

# %%
len(stocks_result)
# Out:
# 4607

# %%
stocks_df = pd.DataFrame(stocks_result)

# %%
stocks_df.to_parquet(os.path.join(DATA_PATH, 'stocks.parquet'), index=False)

# %% [markdown]
# # 3. Get stock's info
#
# This is what we're using to extract ticker's relevant info (display name, sector, C-level members, etc.)

# %%
stocks_df = pd.read_parquet(os.path.join(DATA_PATH, 'stocks.parquet'))

# %%
def fetch_stock_info(symbol):
    try:
        t = yf.Ticker(symbol)
        return t.info
    except:
        return {}

# %%
all_rows = []

for symbol in stocks_df['symbol']:
    try:
        info = fetch_stock_info(symbol)
        all_rows.append({
            'symbol': symbol,
            'info': info,
        })
        
        # Sleep to avoid API throttling
        time.sleep(0.05)
    
    except Exception as e:
        all_rows.append({
            'symbol': symbol,
            'info': {},
        })

# %%
all_rows = [r for r in all_rows if len(r['info'].keys()) > 0]

# %%
len(all_rows)
# Out:
# 4607

# %%
# convert to dataframe
info_df = pd.DataFrame(all_rows)

info_df.head()
# Out:
#   symbol                                               info
# 0   ZYXI  {'address1': '9655 Maroon Circle', 'city': 'En...
# 1   ZYME  {'address1': '108 Patriot Drive', 'address2': ...
# 2    ZWS  {'address1': '511 West Freshwater Way', 'city'...
# 3   ZVRA  {'address1': '1180 Celebration Boulevard', 'ad...
# 4   ZVIA  {'address1': '15821 Ventura Boulevard', 'addre...

# %%
df_final = pd.json_normalize(info_df['info'])

# %%
df_final.dtypes
# Out:
# address1                              object
# city                                  object
# state                                 object
# zip                                   object
# country                               object
# phone                                 object
# fax                                   object
# website                               object
# industry                              object
# industryKey                           object
# industryDisp                          object
# sector                                object
# sectorKey                             object
# sectorDisp                            object
# longBusinessSummary                   object
# fullTimeEmployees                    float64
# companyOfficers                       object
# compensationAsOfEpochDate            float64
# executiveTeam                         object
# maxAge                                 int64
# priceHint                              int64
# previousClose                        float64
# open                                 float64
# dayLow                               float64
# dayHigh                              float64
# regularMarketPreviousClose           float64
# regularMarketOpen                    float64
# regularMarketDayLow                  float64
# regularMarketDayHigh                 float64
# exDividendDate                       float64
# payoutRatio                          float64
# beta                                 float64
# forwardPE                            float64
# volume                               float64
# regularMarketVolume                  float64
# averageVolume                        float64
# averageVolume10days                  float64
# averageDailyVolume10Day              float64
# bid                                  float64
# ask                                  float64
# bidSize                              float64
# askSize                              float64
# marketCap                            float64
# fiftyTwoWeekLow                      float64
# fiftyTwoWeekHigh                     float64
# allTimeHigh                          float64
# allTimeLow                           float64
# priceToSalesTrailing12Months          object
# fiftyDayAverage                      float64
# twoHundredDayAverage                 float64
# trailingAnnualDividendRate           float64
# trailingAnnualDividendYield          float64
# currency                              object
# tradeable                               bool
# enterpriseValue                      float64
# profitMargins                        float64
# floatShares                          float64
# sharesOutstanding                    float64
# sharesShort                          float64
# sharesShortPriorMonth                float64
# sharesShortPreviousMonthDate         float64
# dateShortInterest                    float64
# sharesPercentSharesOut               float64
# heldPercentInsiders                  float64
# heldPercentInstitutions              float64
# shortRatio                           float64
# shortPercentOfFloat                  float64
# impliedSharesOutstanding             float64
# bookValue                            float64
# lastFiscalYearEnd                    float64
# nextFiscalYearEnd                    float64
# mostRecentQuarter                    float64
# netIncomeToCommon                    float64
# trailingEps                          float64
# forwardEps                           float64
# lastSplitFactor                       object
# lastSplitDate                        float64
# enterpriseToRevenue                  float64
# enterpriseToEbitda                   float64
# 52WeekChange                         float64
# SandP52WeekChange                    float64
# lastDividendValue                    float64
# lastDividendDate                     float64
# quoteType                             object
# currentPrice                         float64
# targetHighPrice                      float64
# targetLowPrice                       float64
# targetMeanPrice                      float64
# targetMedianPrice                    float64
# recommendationMean                   float64
# recommendationKey                     object
# numberOfAnalystOpinions              float64
# totalCash                            float64
# totalCashPerShare                    float64
# ebitda                               float64
# totalDebt                            float64
# quickRatio                           float64
# currentRatio                         float64
# totalRevenue                         float64
# revenuePerShare                      float64
# returnOnAssets                       float64
# grossProfits                         float64
# freeCashflow                         float64
# operatingCashflow                    float64
# revenueGrowth                        float64
# grossMargins                         float64
# ebitdaMargins                        float64
# operatingMargins                     float64
# financialCurrency                     object
# symbol                                object
# language                              object
# region                                object
# typeDisp                              object
# quoteSourceName                       object
# triggerable                             bool
# customPriceAlertConfidence            object
# marketState                           object
# corporateActions                      object
# preMarketTime                        float64
# regularMarketTime                      int64
# exchange                              object
# messageBoardId                        object
# exchangeTimezoneName                  object
# exchangeTimezoneShortName             object
# gmtOffSetMilliseconds                  int64
# market                                object
# esgPopulated                            bool
# regularMarketChangePercent           float64
# regularMarketPrice                   float64
# hasPrePostMarketData                    bool
# firstTradeDateMilliseconds           float64
# preMarketChange                      float64
# preMarketChangePercent               float64
# preMarketPrice                       float64
# regularMarketChange                  float64
# regularMarketDayRange                 object
# fullExchangeName                      object
# averageDailyVolume3Month             float64
# fiftyTwoWeekLowChange                float64
# fiftyTwoWeekLowChangePercent         float64
# fiftyTwoWeekRange                     object
# fiftyTwoWeekHighChange               float64
# fiftyTwoWeekHighChangePercent        float64
# fiftyTwoWeekChangePercent            float64
# dividendDate                         float64
# earningsTimestampStart               float64
# earningsTimestampEnd                 float64
# earningsCallTimestampStart           float64
# earningsCallTimestampEnd             float64
# isEarningsDateEstimate                object
# epsTrailingTwelveMonths              float64
# epsForward                           float64
# fiftyDayAverageChange                float64
# fiftyDayAverageChangePercent         float64
# twoHundredDayAverageChange           float64
# twoHundredDayAverageChangePercent    float64
# priceToBook                          float64
# sourceInterval                         int64
# exchangeDataDelayedBy                  int64
# averageAnalystRating                  object
# cryptoTradeable                         bool
# shortName                             object
# longName                              object
# displayName                           object
# trailingPegRatio                     float64
# address2                              object
# auditRisk                            float64
# boardRisk                            float64
# compensationRisk                     float64
# shareHolderRightsRisk                float64
# overallRisk                          float64
# governanceEpochDate                  float64
# debtToEquity                         float64
# returnOnEquity                       float64
# earningsTimestamp                    float64
# epsCurrentYear                       float64
# priceEpsCurrentYear                  float64
# ipoExpectedDate                       object
# dividendRate                         float64
# dividendYield                        float64
# fiveYearAvgDividendYield             float64
# trailingPE                            object
# earningsQuarterlyGrowth              float64
# earningsGrowth                       float64
# prevName                              object
# nameChangeDate                        object
# irWebsite                             object
# openInterest                         float64
# pegRatio                             float64
# newListingDate                        object
# prevTicker                            object
# tickerChangeDate                      object
# prevExchange                          object
# exchangeTransferDate                  object
# industrySymbol                        object
# dtype: object

# %%
# replace Infinity values with np.inf
df_final[['priceToSalesTrailing12Months', 'trailingPE']] = df_final[['priceToSalesTrailing12Months', 'trailingPE']].replace('Infinity', np.inf)
# Out:
# /tmp/ipykernel_23789/1314993215.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_final[['priceToSalesTrailing12Months', 'trailingPE']] = df_final[['priceToSalesTrailing12Months', 'trailingPE']].replace('Infinity', np.inf)

# %%
df_final.to_parquet(os.path.join(DATA_PATH, "stocks_info.parquet"))

# %% [markdown]
# # 4. Get stocks' institutional holders

# %%
stocks_df = pd.read_parquet(os.path.join(DATA_PATH, 'stocks.parquet'))

# stocks_df.head()
# Out:
#   symbol
# 0   ZYXI
# 1   ZYME
# 2    ZWS
# 3   ZVRA
# 4   ZVIA

# %%
def get_institutional_holders(symbol):
    try:
        t = yf.Ticker(symbol)
        # Get institutional holders as DataFrame
        holders = t.get_institutional_holders(as_dict=False).to_dict(orient='records')
    except:
        holders = []
    return holders

# %%
all_rows = []

for symbol in stocks_df['symbol']:
    try:
        holders = get_institutional_holders(symbol)
        all_rows.append({
            'symbol': symbol,
            'holders': holders,
        })
        
        # Sleep to avoid API throttling
        time.sleep(0.1)
    
    except Exception as e:
        all_rows.append({
            'symbol': symbol,
            'holders': [],
        })
# Out:
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: XRPM"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: VUSV"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: VUSG"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: VDIG"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: TSOL"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: TEST"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: NVIT"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: MSST"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: DLNV"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: CIFU"}}}

# %%
# convert to dataframe
holders_df = pd.DataFrame(all_rows)

holders_df.head()
# Out:
#   symbol                                            holders
# 0   ZYXI  [{'Date Reported': 2025-09-30 00:00:00, 'Holde...
# 1   ZYME  [{'Date Reported': 2025-09-30 00:00:00, 'Holde...
# 2    ZWS  [{'Date Reported': 2025-09-30 00:00:00, 'Holde...
# 3   ZVRA  [{'Date Reported': 2025-09-30 00:00:00, 'Holde...
# 4   ZVIA  [{'Date Reported': 2025-09-30 00:00:00, 'Holde...

# %%
holders_df.to_parquet(os.path.join(DATA_PATH, "institutional_holders.parquet"))

# %% [markdown]
# # 5. Get stocks' mutual fund holders

# %%
stocks_df = pd.read_parquet(os.path.join(DATA_PATH, 'stocks.parquet'))

stocks_df['symbol'].head()
# Out:
# 0    ZYXI
# 1    ZYME
# 2     ZWS
# 3    ZVRA
# 4    ZVIA
# Name: symbol, dtype: object

# %%
def get_mutualfund_holders(symbol):
    try:
        t = yf.Ticker(symbol)
        # Get institutional holders as DataFrame
        holders = t.get_mutualfund_holders(as_dict=False).to_dict(orient='records')
    except:
        holders = []
    return holders

# %%
all_rows = []

for symbol in stocks_df['symbol']:
    try:
        holders = get_mutualfund_holders(symbol)
        all_rows.append({
            'symbol': symbol,
            'holders': holders,
        })
        
        # Sleep to avoid API throttling
        time.sleep(0.05)
    
    except Exception as e:
        all_rows.append({
            'symbol': symbol,
            'holders': [],
        })
# Out:
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: XRPM"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: VUSV"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: VUSG"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: VDIG"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: TSOL"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: TEST"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: NVIT"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: MSST"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: DLNV"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"No fundamentals data found for symbol: CIFU"}}}

# %%
# convert to dataframe
holders_df = pd.DataFrame(all_rows)

holders_df.head()
# Out:
#   symbol                                            holders
# 0   ZYXI  [{'Date Reported': 2025-09-30 00:00:00, 'Holde...
# 1   ZYME  [{'Date Reported': 2025-09-30 00:00:00, 'Holde...
# 2    ZWS  [{'Date Reported': 2025-09-30 00:00:00, 'Holde...
# 3   ZVRA  [{'Date Reported': 2025-09-30 00:00:00, 'Holde...
# 4   ZVIA  [{'Date Reported': 2025-09-30 00:00:00, 'Holde...

# %%
holders_df.to_parquet(os.path.join(DATA_PATH, "mutualfund_holders.parquet"))

# %% [markdown]
# # 6. Get stock's related tickers in latest 10 pieces of news featuring it

# %%
stocks_df = pd.read_parquet(os.path.join(DATA_PATH, 'stocks.parquet'))

stocks_df['symbol'].head()
# Out:
# 0    ZYXI
# 1    ZYME
# 2     ZWS
# 3    ZVRA
# 4    ZVIA
# Name: symbol, dtype: object

# %%
def get_related_tickers(symbol, news_count=10):
    try:
        search = yf.Search(symbol, news_count=news_count)
        news = [n.get('relatedTickers', []) for n in search.news]
        related_tickers = list(set({item for sublist in news for item in sublist}))
    except:
        related_tickers = []
    return related_tickers

# %%
all_rows = []

for symbol in stocks_df['symbol']:
    try:
        related = get_related_tickers(symbol)
        all_rows.append({
            'symbol': symbol,
            'related_tickers': related,
        })
        
        # Sleep to avoid API throttling
        time.sleep(0.05)
    
    except Exception as e:
        all_rows.append({
            'symbol': symbol,
            'related_tickers': [],
        })

# %%
# convert to dataframe
related_df = pd.DataFrame(all_rows)

related_df.head()
# Out:
#   symbol                                    related_tickers
# 0   ZYXI  [ESSITY-B.ST, CLSK, NVDA, BITF, ASST, IBIT, XR...
# 1   ZYME                                       [JAZZ, ZYME]
# 2    ZWS  [ZGSB.TO, ZWB.TO, ZGLD.TO, ZCDB.TO, ZHU.TO, ZM...
# 3   ZVRA  [XOMA, EPIX, ZVRA, MURA, TSBX, XOMAP, XOMAO, L...
# 4   ZVIA  [UPLD, ^SPX, WMT, BYND, PLTR, ZVIA, KHC, PRKS,...

# %%
related_df.to_parquet(os.path.join(DATA_PATH, "stocks_related_tickers.parquet"))
