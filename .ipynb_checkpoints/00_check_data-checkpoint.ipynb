# %%
# from pytickersymbols import PyTickerSymbolsL
import yfinance as yf
import pandas as pd
import os
import json

import time

# %%
pd.set_option("display.max_rows", None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pd.set_options('display.max_rows', None)
#
# AttributeError: module 'pandas' has no attribute 'set_options'

# %%
DATA_PATH = './data'
os.makedirs(DATA_PATH, exist_ok=True)

# %%
df = pd.read_parquet(os.path.join(DATA_PATH, 'stocks.parquet'))

# %%
df.iloc[0].T
# Out:
# language                                 en-US
# region                                      US
# quoteType                               EQUITY
# typeDisp                                Equity
# quoteSourceName         Nasdaq Real Time Price
#                                  ...
# prevTicker                                None
# tickerChangeDate                          None
# prevExchange                              None
# exchangeTransferDate                      None
# newListingDate                            None
# Name: 0, Length: 95, dtype: object
